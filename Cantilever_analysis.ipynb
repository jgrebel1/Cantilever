# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_1 = []
y_1 = []

for line in open('20150806_displacement_field.txt'):
    if line[0] == '%':
        continue
    a = [x.strip() for x in line.split(" ")]
    a = filter(lambda a: a != '', a)
    x_1.append(float(a[0]))
    y_1.append(float(a[1]))
y_2 = np.absolute(y_1)
y_3 = [y*1e-6 for y in y_2]

# %%
plt.figure()
plt.plot(x_1, y_3)
plt.show()

# %%
range(min_w_d,step_w_d,mid_w_d1),range(mid_w_d3,step_w_d, max_w_d)
